# %%
import pandas as pd

customers_df = pd.read_json("noahs-customers.jsonl", lines=True)
orders_df = pd.read_json("noahs-orders.jsonl", convert_dates=['ordered', 'shipped'], lines=True)
products_df = pd.read_json("noahs-products.jsonl", lines=True)

# %% [markdown]
# SKU IDs:
#
# - `PET` pets
# - `COL` collectible
# - `DLI` deli
# - `BKY` bakery
# - `HOM` household goods

# %%
norm_orders_df = orders_df.explode('items', ignore_index=True)
norm_orders_df = pd.concat([norm_orders_df.drop(columns=['items']), pd.json_normalize(norm_orders_df['items'])], axis=1)

# %%
df = norm_orders_df.join(
    customers_df.set_index('customerid'),
    on='customerid',
).join(products_df.set_index('sku'), on='sku')

# %%
products_df[products_df['sku'].str.contains('COL')]
# Out:
#           sku                           desc  wholesale_cost  \
# 5     COL0037         Noah's Jewelry (green)           28.32
# 6     COL0041    Noah's Ark Model (HO Scale)         2487.35
# 8     COL0065         Noah's Jewelry (mauve)           33.52
# 21    COL0166    Noah's Action Figure (blue)           13.98
# 22    COL0167       Noah's Bobblehead (blue)            5.36
# ...       ...                            ...             ...
# 1191  COL9349  Noah's Action Figure (orange)           15.47
# 1202  COL9420         Noah's Jewelry (amber)           30.01
# 1246  COL9773        Noah's Poster (magenta)            4.13
# 1253  COL9819         Noah's Lunchbox (blue)            9.87
# 1268  COL9948       Noah's Jewelry (magenta)           32.97
#
#                              dims_cm
# 5                  [17.4, 11.2, 5.7]
# 6                    [7.2, 4.3, 0.4]
# 8                 [19.0, 12.2, 10.5]
# 21                  [12.1, 7.7, 7.2]
# 22    [8.9, 5.6, 0.6000000000000001]
# ...                              ...
# 1191              [16.6, 12.9, 11.9]
# 1202                [13.8, 9.1, 4.9]
# 1246                 [7.2, 4.9, 1.9]
# 1253                [14.2, 4.1, 3.3]
# 1268               [18.0, 17.5, 6.2]
#
# [85 rows x 4 columns]

# %%
df[df['sku'].str.contains('COL')][['customerid', 'sku']].drop_duplicates().groupby('customerid')['sku'].agg("count").sort_values(ascending=False)
# Out:
# customerid
# 3808    85
# 4254    31
# 8665    30
# 3914    30
# 6855    30
#         ..
# 3570     1
# 3569     1
# 9078     1
# 9073     1
# 9184     1
# Name: sku, Length: 3290, dtype: int64

# %%
df[df['customerid'] == 3808]
# Out:
#         orderid  customerid             ordered             shipped  total  \
# 32         1015        3808 2017-01-31 10:29:22 2017-01-31 15:15:00  13.48
# 370        1184        3808 2017-02-01 22:19:28 2017-02-07 13:00:00  13.81
# 584        1295        3808 2017-02-02 23:25:54 2017-02-04 09:30:00  11.78
# 768        1381        3808 2017-02-03 17:56:15 2017-02-05 10:30:00   3.87
# 840        1416        3808 2017-02-04 01:06:07 2017-02-04 12:30:00   3.89
# ...         ...         ...                 ...                 ...    ...
# 412177   206967        3808 2022-10-04 18:14:34 2022-10-05 19:00:00   6.29
# 425143   213533        3808 2022-12-10 00:01:58 2022-12-10 17:15:00   5.75
# 425144   213533        3808 2022-12-10 00:01:58 2022-12-10 17:15:00   5.75
# 425145   213533        3808 2022-12-10 00:01:58 2022-12-10 17:15:00   5.75
# 425146   213533        3808 2022-12-10 00:01:58 2022-12-10 17:15:00   5.75
#
#             sku  qty  unit_price         name        address  \
# 32      COL8357    1       13.48  James Smith  132 Spring St
# 370     COL6858    1       13.81  James Smith  132 Spring St
# 584     COL6461    1       11.78  James Smith  132 Spring St
# 768     COL7866    1        3.87  James Smith  132 Spring St
# 840     COL7036    1        3.89  James Smith  132 Spring St
# ...         ...  ...         ...          ...            ...
# 412177  DLI6192    1        1.35  James Smith  132 Spring St
# 425143  BKY5319    1        1.47  James Smith  132 Spring St
# 425144  TOY9241    1        1.45  James Smith  132 Spring St
# 425145  PET5897    1        1.25  James Smith  132 Spring St
# 425146  PET5402    1        1.58  James Smith  132 Spring St
#
#                citystatezip   birthdate         phone          timezone  \
# 32      Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 370     Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 584     Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 768     Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 840     Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# ...                     ...         ...           ...               ...
# 412177  Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 425143  Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 425144  Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 425145  Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
# 425146  Manhattan, NY 10012  1953-12-10  212-547-3518  America/New_York
#
#               lat      long                                      desc  \
# 32      40.724902 -74.00252                   Noah's Lunchbox (mauve)
# 370     40.724902 -74.00252                      Noah's Jersey (blue)
# 584     40.724902 -74.00252                     Noah's Jersey (white)
# 768     40.724902 -74.00252                   Noah's Gift Box (white)
# 840     40.724902 -74.00252                     Noah's Gift Box (red)
# ...           ...       ...                                       ...
# 412177  40.724902 -74.00252                   Salted Cabbage Sandwich
# 425143  40.724902 -74.00252                      Raspberry Mandelbrot
# 425144  40.724902 -74.00252                     Mechanical Fidget Toy
# 425145  40.724902 -74.00252                 Dry Cat Food, Beef & Beef
# 425146  40.724902 -74.00252  Vegan Senior Cat Food, Pumpkin & Pumpkin
#
#         wholesale_cost            dims_cm
# 32                9.21  [19.9, 17.4, 9.8]
# 370              10.60   [16.0, 6.6, 4.0]
# 584               9.36   [18.8, 3.8, 1.3]
# 768               3.06    [8.8, 7.4, 5.9]
# 840               3.04  [18.5, 15.7, 6.3]
# ...                ...                ...
# 412177            1.13    [4.0, 1.6, 1.5]
# 425143            1.09  [12.6, 12.1, 2.8]
# 425144            1.10  [14.5, 12.0, 1.3]
# 425145            0.99   [14.7, 8.9, 0.5]
# 425146            1.29  [19.5, 15.0, 2.7]
#
# [429 rows x 19 columns]
